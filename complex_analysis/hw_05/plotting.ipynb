# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
r = 10
n = 1

t = np.linspace(0, 1, 30)
z_1 = lambda t: -r + (r - 1 - (1/n))*t
z_3 = lambda t: - 1 + (1/n) + 2*(1 - (1/n))*t
z_5 = lambda t: 1 + (1/n) + (r - 1 - (1/n))*t

plt.plot(t, z_5(t))
plt.grid("--")
plt.show()
